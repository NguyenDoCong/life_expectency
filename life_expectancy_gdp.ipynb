# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
data = pd.read_csv('all_data.csv')

# %%
print(data.head())
# Out:
#   Country  Year  Life expectancy at birth (years)           GDP
# 0   Chile  2000                              77.3  7.786093e+10
# 1   Chile  2001                              77.3  7.097992e+10
# 2   Chile  2002                              77.8  6.973681e+10
# 3   Chile  2003                              77.9  7.564346e+10
# 4   Chile  2004                              78.0  9.921039e+10

# %%
print(data.describe(include='all'))
# Out:
#        Country         Year  Life expectancy at birth (years)           GDP
# count       96    96.000000                         96.000000  9.600000e+01
# unique       6          NaN                               NaN           NaN
# top      Chile          NaN                               NaN           NaN
# freq        16          NaN                               NaN           NaN
# mean       NaN  2007.500000                         72.789583  3.880499e+12
# std        NaN     4.633971                         10.672882  5.197561e+12
# min        NaN  2000.000000                         44.300000  4.415703e+09
# 25%        NaN  2003.750000                         74.475000  1.733018e+11
# 50%        NaN  2007.500000                         76.750000  1.280220e+12
# 75%        NaN  2011.250000                         78.900000  4.067510e+12
# max        NaN  2015.000000                         81.000000  1.810000e+13

# %%
print(data.info)
# Out:
# <bound method DataFrame.info of      Country  Year  Life expectancy at birth (years)           GDP
# 0      Chile  2000                              77.3  7.786093e+10
# 1      Chile  2001                              77.3  7.097992e+10
# 2      Chile  2002                              77.8  6.973681e+10
# 3      Chile  2003                              77.9  7.564346e+10
# 4      Chile  2004                              78.0  9.921039e+10
# ..       ...   ...                               ...           ...
# 91  Zimbabwe  2011                              54.9  1.209845e+10
# 92  Zimbabwe  2012                              56.6  1.424249e+10
# 93  Zimbabwe  2013                              58.0  1.545177e+10
# 94  Zimbabwe  2014                              59.2  1.589105e+10
# 95  Zimbabwe  2015                              60.7  1.630467e+10
#
# [96 rows x 4 columns]>

# %%
sns.lineplot(data=data,x='Year',y='Life expectancy at birth (years)')
plt.savefig('by_year.png')
plt.show()
plt.clf()

# %%
sns.lineplot(data=data,x='Year',y='GDP')
plt.savefig('gdp_year.png')
plt.show()
plt.clf()

# %%
print(stats.pearsonr(data['GDP'],data['Life expectancy at birth (years)']))
# Out:
# PearsonRResult(statistic=0.343206748449156, pvalue=0.0006187129569469888)

# %%
zimbabwe = data[data['Country']=='Zimbabwe']
others = data[data['Country']!='Zimbabwe']
life_65 = data[data['Life expectancy at birth (years)']<=65]
sns.lmplot(data=zimbabwe,x='Life expectancy at birth (years)',y='GDP',hue='Country')
plt.savefig('zim_gdp_life.png')
plt.show()
plt.clf()
sns.lmplot(data=others,x='Life expectancy at birth (years)',y='GDP',hue='Country')
plt.savefig('others.png')
plt.show()
plt.clf()

# %%
g=sns.boxplot(data=zimbabwe,x='Country',y='Life expectancy at birth (years)')
plt.savefig('zim_life_plot.png')
plt.show()
plt.clf()
g=sns.boxplot(data=others,x='Country',y='Life expectancy at birth (years)')
g.set_xticks(range(5))
g.set_xticklabels(['Chile','China','Germany','Mexico','USA'])
plt.savefig('others_life_plot.png')
plt.show()
plt.clf()

# %%
sns.histplot(data=zimbabwe,x='Life expectancy at birth (years)')
plt.savefig('zim_dist.png')
plt.show()
plt.clf()

# %%
sns.histplot(data=others,x='Life expectancy at birth (years)',hue='Country',element='step')
plt.savefig('others_dist.png')
plt.show()
plt.clf()
